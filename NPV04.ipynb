# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                   <b> Inclass - Lab <br> (Day 4) </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ##  Table of Content
#
# 1. **[Plots using Library Matplotlib ](#matplotlib)**
# 2. **[Plots using Library Seaborn ](#seaborn)**

# %% [markdown]
# ### Let us import the required libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='matplotlib'></a>
# ## 1. Plots using Library Matplotlib

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Plot a scatter plot for the following data. Also add title and axis names</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
#             medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)
plt.scatter(bmi,medical_claim)
plt.xlabel('bmi')
plt.ylabel('medical_claim')
plt.title('bmi vs medical_claim ')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Write a code to get the following output </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="cos_curve.png" width = '500' >

# %%
import seaborn as sns

# import the library NumPy 
import numpy as np

# import the library Pandas
import pandas as pd

# import the library matplotlib
import matplotlib.pyplot as plt

# %%
x=np.linspace(1,20,50)
y=np.cos(x)
plt.plot(x,y)
plt.scatter(x,y,c='black')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 3. Plot cosine curve and exponential curve for natural numbers from 0.1 to 20, in the same plot (get the following output)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="dual_axis.png" width ='500' >

# %%
x=np.arange(0.1,21)
y1=np.exp(x)
y2=np.cos(x)
plt.plot(x,y1,y2)
plt.scatter(x,y2,c='black')
plt.legend(["dataset1","dataset2"])
plt.show()

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
df={'year':[2001,2002,2003,2004,2005],'Import':[54.4,53.8,61.6,74.15,89.33],'Export':[42.5,44.5,48.3,57.24,69.18]}
df1=pd.DataFrame(df)
df1.plot.bar(x='year')
plt.show()

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Plot a pie chart for the following data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         prices = [50, 25, 50, 20]
#         labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
prices = [50, 25, 50, 20]
labels = ['Apple', 'Orange','Banana', 'Mango']
plt.pie(prices,autopct='%.2f%%',radius=1.2,labels=labels)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Following is the information release after the Indian budget is declared. Plot a pie chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
Income_From=['Corporation Tax','Income Tax','Customs','Union Excise Duties','GST & Other Taxes','Non-Tax Revenue','Non-Debt Capital Receipts','Borrowings and Other Liabilities']
amount_inpaise=[21,16,4,8,19,9,3,20]
plt.pie(amount_inpaise,autopct='%.2f%%',radius=1.2,labels=Income_From)
plt.show()

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Create a tuple of numbers 12, 34, 54, 45, 45, 45, 23, 23, 54 and plot a simple line plot
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=(12, 34, 54, 45, 45, 45, 23, 23, 54)
plt.plot(x)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df=pd.read_csv('C:/Users/HP/Downloads/Returns.csv')
df.head()
# Out:
#    Day       TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# 0    1  1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 1    2  1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 2    3  0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 3    4 -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 4    5  1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111

# %%
plt.plot(df['Day'],df['TCS'])
plt.plot(df['Day'],df['HDFCBANK'])
plt.plot(df['Day'],df['JINDALSTEL'])
plt.plot(df['Day'],df['TATAMOTORS'])
plt.plot(df['Day'],df['INFY'])
plt.plot(df['Day'],df['BOSCHLTD'])
plt.show()

# %% [markdown]
# <a id='seaborn'></a>
# ## 2. Plots using Library Seaborn

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Plot a  strip plot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
jsn=pd.read_json('C:/Users/HP/Downloads/iris.json')
jsn.head()
sns.stripplot(data=jsn,x='sepalLength',y='sepalWidth',hue='species')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 11. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_age_height=pd.read_csv('C:/Users/HP/Downloads/age_height.csv')
corr_matrix = df_age_height.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13a. Using the following data, plot a scatter plot with  the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
#             y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
y = (145, 456, 764, 234, 156, 786, 345, 455, 675)
sns.scatterplot(x,y)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13b. Using the data generated in question 3, plot a scatter plot with the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=np.arange(0.1,21)
y1=np.exp(x)
y2=np.cos(x)
sns.scatterplot(x,y1)
sns.scatterplot(x,y2)
plt.legend(["dataset1","dataset2"])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 14. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_diamonds=sns.load_dataset('diamonds')
corr_matrix = df_tips.corr()
sns.heatmap(corr_matrix, annot = True)
sns.catplot(x='cut',y='carat',data=df_diamonds,kind='violin')
sns.catplot(x='cut',y='carat',data=df_diamonds,kind='box')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 15. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df=np.random.rand(100)
plt.hist(df,color='green',edgecolor='black')
plt.show()

# %%
sns.distplot(df,hist_kws={'color':'green','edgecolor':'black'})
plt.show()
